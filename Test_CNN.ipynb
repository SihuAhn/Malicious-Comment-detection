# %%
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Activation, Dropout, Conv1D, MaxPooling1D
from keras.preprocessing import sequence
from keras.utils import np_utils
from gensim.models.word2vec import Word2Vec
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix


import hgtk as hg 
#https://github.com/bluedisk/hangul-toolkit/
import konlpy as kn
from konlpy.tag import Kkma
kor_tagger = Kkma()

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pyprind
import os
# Out:
# Using TensorFlow backend.
# C:\Users\lmgtt\Anaconda3\envs\tensorflow\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
sulliComments = pd.read_csv('sulliComments_nouns.csv',encoding='cp949')

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
X_data = sulliComments['comment']
y_data = sulliComments['bad']


tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_data) #5572개의 행을 가진 X의 각 행에 토큰화를 수행
sequences = tokenizer.texts_to_sequences(X_data) #단어를 숫자값, 인덱스로 변환하여 저장

print(sequences[:5])
# Out:
# [[555, 22, 14, 1, 15, 16], [894, 160, 11, 2, 12], [1, 21, 10, 329, 2, 32], [47, 2, 238], [23, 19]]

# %%
X_data = sulliComments['comment']
y_data = sulliComments['bad']
print('댓글의 개수: {}'.format(len(X_data)))
print('레이블의 개수: {}'.format(len(y_data)))
# Out:
# 댓글의 개수: 1200
# 레이블의 개수: 1200

# %%
word_to_index = tokenizer.word_index
print(word_to_index)
# Out:
# {'관': 1, 'ㅈㄲㅈ': 2, '리': 3, '악': 4, '플': 5, '거': 6, '설': 7, '악플': 8, '사람': 9, '종': 10, 'ㅈ': 11, 'ㄲ': 12, '설리': 13, '라': 14, '관종년': 15, '종년': 16, '정신병자': 17, '악플러': 18, '명복': 19, '러': 20, '관종': 21, '나': 22, '고인': 23, '연예인': 24, '노력': 25, '생각': 26, '때': 27, '젖꼭지': 28, '뭐': 29, '말': 30, '걸레': 31, '듯': 32, '금붕어': 33, '노브': 34, '댓': 35, '글': 36, '애': 37, '수': 38, '자살': 39, '관심': 40, '개': 41, '안': 42, '사랑': 43, '너': 44, '개구리': 45, '일': 46, '병신': 47, '나이': 48, '얼굴': 49, '기사': 50, '여자': 51, '남': 52, '퇴물': 53, '행복': 54, '해': 55, '노출': 56, '니': 57, '노브라': 58, '년': 59, '길': 60, '정신': 61, '짓': 62, '얘': 63, '댓글': 64, '지': 65, '마약': 66, '야': 67, '줄': 68, '무엇': 69, '여': 70, '터': 71, '니들': 72, '때문': 73, '내': 74, '마음': 75, '곳': 76, '진리': 77, '본인': 78, '악플러들': 79, '연기': 80, '자기': 81, '세상': 82, '오보': 83, '우리': 84, '스타': 85, '아이': 86, '이것': 87, '거지': 88, '선택': 89, 'ㅠ': 90, '데': 91, '종이': 92, '배우': 93, '실명제': 94, '인': 95, '인생': 96, '속': 97, '발': 98, '우울증': 99, '당': 100, '누': 101, '사실': 102, '하나': 103, '새끼': 104, '관종이': 105, '마라': 106, 'ㅉㅉ': 107, '진짜': 108, '하': 109, '관종짓': 110, '누구': 111, '임': 112, '에로': 113, '돈': 114, '맘': 115, '병신년': 116, '기자': 117, '한번': 118, '혼자': 119, '척': 120, '고통': 121, 'ㅋ': 122, '미': 123, '성희롱': 124, '건': 125, '전': 126, '남자': 127, '지금': 128, '놈': 129, '이': 130, '탈': 131, '문제
': 346, '강': 347, '젠': 348, '존재': 349, '옆': 350, '골': 351, '일본': 352, '창녀': 353, '초': 354, '스트레스': 355, 'ㅡ': 356, '능력': 357, '최고': 358, '뒤': 359, '바래요': 360, '발언': 361, '꿈': 362, '시작': 363, '가수': 364, '거임': 365, '살인자': 366, '사회': 367, '지옥': 368, '비주얼': 369, '완벽': 370, '2': 371, '느낌': 372, '분': 373, '부모': 374, '애도': 375, '다음': 376, '소신': 377, '사': 378, '그곳': 379, '소리': 380, '일반인': 381, '그룹': 382, '태': 383 ...

# %%
vocab_size = len(word_to_index)+1
print('단어 집합의 크기: {}'.format((vocab_size)))
# Out:
# 단어 집합의 크기: 2573

# %%
n_of_train = int(1200 * 0.8)
n_of_test = int(1200 - n_of_train)
print(n_of_train)
print(n_of_test)
# Out:
# 960
# 240

# %%
X_data=sequences
print('댓글의 최대 길이 : %d' % max(len(l) for l in X_data))
print('댓글의 평균 길이 : %f' % (sum(map(len, X_data))/len(X_data)))
plt.hist([len(s) for s in X_data], bins=50)
plt.xlabel('length of Data')
plt.ylabel('number of Data')
plt.show()
# Out:
# 댓글의 최대 길이 : 58
# 댓글의 평균 길이 : 7.524167

# %%
max_len = 58
# 전체 데이터셋의 길이는 58로 맞춥니다.
data = pad_sequences(X_data, maxlen=max_len)
print("data shape: ", data.shape)
# Out:
# data shape:  (1200, 58)

# %%
#X_train, X_test, y_train, y_test = train_test_split(data, y_data, test_size=0.2)
X_test = data[n_of_train:] 
y_test = np.array(y_data[n_of_train:]) 
X_train = data[:n_of_train]
y_train = np.array(y_data[:n_of_train])

# %%
from tensorflow.keras.layers import SimpleRNN, Embedding, Dense
from tensorflow.keras.layers import Flatten, Dense, LSTM, Embedding, Activation, Dropout, Conv1D, MaxPooling1D

from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(Embedding(vocab_size, 32, input_length=58))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
# model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

# model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
# model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
# model.add(MaxPooling1D(pool_size=2))

model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# model.summary()
history = model.fit(X_train, y_train, epochs=100, batch_size=60, validation_split=0.2)
# Out:
# Train on 768 samples, validate on 192 samples
# Epoch 1/100
# 768/768 [==============================] - 2s 3ms/sample - loss: 0.6939 - acc: 0.4896 - val_loss: 0.6920 - val_acc: 0.5000
# Epoch 2/100
# 768/768 [==============================] - 0s 380us/sample - loss: 0.6891 - acc: 0.6901 - val_loss: 0.6894 - val_acc: 0.7083
# Epoch 3/100
# 768/768 [==============================] - 0s 401us/sample - loss: 0.6803 - acc: 0.7513 - val_loss: 0.6830 - val_acc: 0.6458
# Epoch 4/100
# 768/768 [==============================] - 0s 473us/sample - loss: 0.6580 - acc: 0.8932 - val_loss: 0.6618 - val_acc: 0.7552
# Epoch 5/100
# 768/768 [==============================] - 0s 629us/sample - loss: 0.5926 - acc: 0.9167 - val_loss: 0.5940 - val_acc: 0.8073
# Epoch 6/100
# 768/768 [==============================] - 0s 234us/sample - loss: 0.4629 - acc: 0.9193 - val_loss: 0.4794 - val_acc: 0.8177
# Epoch 7/100
# 768/768 [==============================] - 0s 307us/sample - loss: 0.0314 - acc: 0.9883 - val_loss: 0.3430 - val_acc: 0.8750
# Epoch 69/100
# 768/768 [==============================] - 0s 421us/sample - loss: 0.0316 - acc: 0.9883 - val_loss: 0.3322 - val_acc: 0.8802
# Epoch 70/100
# 768/768 [==============================] - 0s 465us/sample - loss: 0.0305 - acc: 0.9883 - val_loss: 0.3399 - val_acc: 0.8750
# Epoch 71/100
# 768/768 [==============================] - 0s 279us/sample - loss: 0.0304 - acc: 0.9883 - val_loss: 0.3434 - val_acc: 0.8750
# Epoch 72/100
# 768/768 [==============================] - 0s 197us/sample - loss: 0.0308 - acc: 0.9883 - val_loss: 0.3287 - val_acc: 0.8802
# Epoch 73/100
# 768/768 [==============================] - 0s 306us/sample - loss: 0.0300 - acc: 0.9883 - val_loss: 0.3326 - val_acc: 0.8750
# Epoch 74/100
# 768/768 [==============================] - 0s 254us/sample - loss: 0.0309 - acc: 0.9883 - val_loss: 0.3468 - val_acc: 0.8750
# Epoch 75/100
# 768/768 [==============================] - 0s 328us/sample - loss: 0.0303 - acc: 0.9883 - val_loss: 0.3274 - val_acc: 0.8802
# Epoch 76/100
# 768/768 [==============================] - 0s 291us/sample - loss: 0.0304 - acc: 0.9883 - val_loss: 0.3322 - val_acc: 0.8802
# Epoch 77/100
# 768/768 [==============================] - 0s 179us/sample - loss: 0.0313 - acc: 0.9883 - val_loss: 0.3430 - val_acc: 0.8802
# Epoch 78/100
# 768/768 [==============================] - 0s 445us/sample - loss: 0.0310 - acc: 0.9883 - val_loss: 0.3324 - val_acc: 0.8802
# Epoch 79/100
# 768/768 [==============================] - 0s 333us/sample - loss: 0.0297 - acc: 0.9883 - val_loss: 0.3441 - val_acc: 0.8802
# Epoch 80/100
# 768/768 [==============================] - 0s 270us/sample - loss: 0.0310 - acc: 0.9883 - val_loss: 0.3401 - val_acc: 0.8802
# Epoch 81/100
# 768/768 [==============================] - 1s 905us/sample - loss: 0.0308 - acc: 0.9883 - val_loss: 0.3415 - val_acc: 0.8802
# Epoch 82/100
# 768/768 [==============================] - 0s 239us/sample - loss: 0.0300 - acc: 0.9883 - val_loss: 0.3443 - val_acc: 0.8802
# Epoch 83/100
# 768/768 [==============================] - 0s 229us/sample - loss: 0.0299 - acc: 0.9883 - val_loss: 0.3413 - val_acc: 0.8750
# Epoch 84/100
# 768/768 [==============================] - 0s 270us/sample - loss: 0.0301 - acc: 0.9883 - val_loss: 0.3445 - val_acc: 0.8802
# Epoch 85/100
# 768/768 [==============================] - 0s 250us/sample - loss: 0.0299 - acc: 0.9883 - val_loss: 0.3484 - val_acc: 0.8802
# Epoch 86/100
# 768/768 [==============================] - 0s 182us/sample - loss: 0.0301 - acc: 0.9883 - val_loss: 0.3480 - val_acc: 0.8802
# Epoch 87/100
# 768/768 [==============================] - 0s 198us/sample - loss: 0.0303 - acc: 0.9883 - val_loss: 0.3430 - val_acc: 0.8750
# Epoch 88/100
# 768/768 [==============================] - 0s 265us/sample - loss: 0.0295 - acc: 0.9883 - val_loss: 0.3501 - val_acc: 0.8802
# Epoch 89/100
# 768/768 [==============================] - 0s 390us/sample - loss: 0.0299 - acc: 0.9883 - val_loss: 0.3571 - val_acc: 0.8750
# Epoch 90/100
# 768/768 [==============================] - 0s 260us/sample - loss: 0.0298 - acc: 0.9883 - val_loss: 0.3482 - val_acc: 0.8750
# Epoch 91/100
# 768/768 [==============================] - 0s 276us/sample - loss: 0.0311 - acc: 0.9883 - val_loss: 0.3455 - val_acc: 0.8802
# Epoch 92/100
# 768/768 [==============================] - 0s 317us/sample - loss: 0.0304 - acc: 0.9883 - val_loss: 0.3623 - val_acc: 0.8750
# Epoch 93/100
# 768/768 [==============================] - 0s 234us/sample - loss: 0.0302 - acc: 0.9883 - val_loss: 0.3575 - val_acc: 0.8750
# Epoch 94/100
# 768/768 [==============================] - 0s 265us/sample - loss: 0.0298 - acc: 0.9883 - val_loss: 0.3513 - val_acc: 0.8750
# Epoch 95/100
# 768/768 [==============================] - 0s 291us/sample - loss: 0.0300 - acc: 0.9883 - val_loss: 0.3556 - val_acc: 0.8750
# Epoch 96/100
# 768/768 [==============================] - 0s 203us/sample - loss: 0.0297 - acc: 0.9883 - val_loss: 0.3595 - val_acc: 0.8750
# Epoch 97/100
# 768/768 [==============================] - 0s 172us/sample - loss: 0.0299 - acc: 0.9883 - val_loss: 0.3610 - val_acc: 0.8750
# Epoch 98/100
# 768/768 [==============================] - 0s 177us/sample - loss: 0.0294 - acc: 0.9883 - val_loss: 0.3529 - val_acc: 0.8750
# Epoch 99/100
# 768/768 [==============================] - 0s 187us/sample - loss: 0.0300 - acc: 0.9883 - val_loss: 0.3543 - val_acc: 0.8750
# Epoch 100/100
# 768/768 [==============================] - 0s 182us/sample - loss: 0.0304 - acc: 0.9883 - val_loss: 0.3690 - val_acc: 0.8750

# %%
epochs = range(1, len(history.history['acc']) + 1)
plt.plot(epochs, history.history['loss'])
plt.plot(epochs, history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history["acc"], label="acc", ls="-", marker="o")
plt.plot(history.history["val_acc"], label="val_acc", ls="-", marker="x")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(loc="best")

# %%
print("\n 테스트 정확도: %.4f" % (model.evaluate(X_test, y_test)[1]))
# Out:
# 240/240 [==============================] - 0s 233us/sample - loss: 0.4488 - acc: 0.8750
#
#  테스트 정확도: 0.8750

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

predict_classes = model.predict_classes(X_test)
#2d to 1d
import itertools
def from_iterable(iterables):
    # chain.from_iterable(['ABC', 'DEF']) --> ['A', 'B', 'C', 'D', 'E', 'F']
    for it in iterables:
        for element in it:
            yield element
y_pred = np.array(list(itertools.chain.from_iterable(predict_classes)))
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted    0    1  All
# True
# 0          103   12  115
# 1           18  107  125
# All        121  119  240

# %%
#confusion_matrix(y_test,y_pred)
print("accuracy score : ", accuracy_score(y_test,y_pred))
print("precision score : ", precision_score(y_test,y_pred))
print("recall score : ", recall_score(y_test,y_pred))
print("f1 score : ", f1_score(y_test,y_pred))
# Out:
# accuracy score :  0.875
# precision score :  0.8991596638655462
# recall score :  0.856
# f1 score :  0.8770491803278688
